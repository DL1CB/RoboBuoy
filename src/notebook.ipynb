# %%
import numpy as np
from pseudo import thrusterMixer
import matplotlib.pyplot as plt
from math import pi

rudder = np.arange(-pi/2,pi/2,0.1)
power = 1/2


plt.plot(rudder,np.clip(rudder*2/pi+power,-1,1))
plt.plot(rudder,np.clip(-rudder*2/pi+power,-1,1))
plt.xlabel("rudder r")
plt.ylabel("power p")
plt.show()
